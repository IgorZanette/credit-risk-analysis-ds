# %% [markdown]
# # 02 - Pré-processamento e Engenharia de Features
#
# Limpeza dos dados (valores ausentes, outliers, tipos), transformação (normalização/padronização) e engenharia de features para preparar o dataset para a modelagem.
#
# **TODO:** preencher com a limpeza e a engenharia de features.
